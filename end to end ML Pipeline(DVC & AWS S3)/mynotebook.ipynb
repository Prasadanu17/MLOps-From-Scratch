# %% [markdown]
# ## Basic Imports

# %%
import sys
print(sys.executable)
# Out:
# Running cells with 'mlops_env (3.11.9) (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/USER/Downloads/MLOPS/end to end ML Pipeline(DVC & AWS S3)/mlops_env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# Importing neccessary libaries
import numpy as np              # For numerical operation
import pandas as pd             # For data manipulation and analysis
import matplotlib.pyplot as plt # For data visualization
# %matplotlib inline

# Importing WordCloud for text visualization
from wordcloud import WordCloud

# Import NLTK for natural language processing
import nltk
from nltk.corpus import stopwords   # For stopwords

# Downloading NLTK data
nltk.download('stopwords')        # Downloading stopwords data
nltk.download('punkt')             # Downloading tokenizer data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       7 # Importing WordCloud for text visualization
# ----> 8 from wordcloud import WordCloud
#      10 # Import NLTK for natural language processing
#      11 import nltk
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Read the CSV file
df= pd.read_csv('spam.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Read the CSV file
# ----> 2 df= pd.read_csv('spam.csv')
#       3
#       4 # Display the first few rows of the DataFrame
#       5 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.drop(cloumns= [''])
