# %%
class employee :
    # special methos/magic method//dunder method -constructor
    def __init__(self):
        print(id(self))
        # print("Started executing attribute/data")
        self.id=33
        self.salary=50000
        self.designation ="SDE"
        # print("attributes/data have been initialized")

    def travel(self,destination):
        print("This travel method was called manually")
        print(f"Employee is travelling to {destination}")
# create an object/instance of class
sam=employee()
print(id(sam))

# printing the attributes
# print(sam.id)

# calling the method 
# sam.travel("chennai")
# Out:
# 2360982434448
# 2360982434448

# %%
print(type(sam))
# Out:
# <class '__main__.employee'>

# %%
lst =[1,2,3]
my_str= "mlops playlist"
my_init =155

print(type(lst))
# Out:
# <class 'list'>

# %%
print(type(my_init))
# Out:
# <class 'int'>

# %%
lst.clear()
print(lst)
# Out:
# []

# %%
my_str.capitalize()
print(my_str)
# Out:
# mlops playlist

# %%
# Adavantages of OOps concept:
#     > You can create your own datatype -with example
a="x"
b="y"

print(a+b)
# Out:
# xy

# %%
from oops_project import Chatbook

lst = [1, 2, 3]

# Function
a1 = len(lst)
print(a1)

# Method
user1 = Chatbook()
user1.sendmsg()
print(user1.name)
# Out:
# 3
# You have signed successfully!!
#
#
# You have signed in Successfully!!
#
#
# following content has been posted {txt}
#
#
# Your message has been sent to 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 10
#       6 a1 = len(lst)
#       7 print(a1)
#       8
#       9 # Method
# ---> 10 user1 = Chatbook()
#      11 user1.sendmsg()
#      12 print(user1.name)
#      13
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:7, in Chatbook.__init__(self)
#       5 self.password = ""
#       6 self.loggedin = False
# ----> 7 self.menu()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:22, in Chatbook.menu(self)
#      10 user_input = input("""Welcome to Chatbook! How would you like to proceed?
#      11
#      12 1. Press 1 to signup
#    (...)     18
#      19 """)
#      21 if user_input == "1":
# ---> 22     self.signup()
#      24 elif user_input == "2":
#      25     self.signin()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:43, in Chatbook.signup(self)
#      41 print("You have signed successfully!!")
#      42 print("\n")
# ---> 43 self.menu()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:25, in Chatbook.menu(self)
#      22     self.signup()
#      24 elif user_input == "2":
# ---> 25     self.signin()
#      27 elif user_input == "3":
#      28     self.my_post()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:57, in Chatbook.signin(self)
#      55         print("Please input correct Credential")
#      56 print("\n")
# ---> 57 self.menu()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:28, in Chatbook.menu(self)
#      25     self.signin()
#      27 elif user_input == "3":
# ---> 28     self.my_post()
#      30 elif user_input == "4":
#      31     self.sendmsg()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:66, in Chatbook.my_post(self)
#      64     print("You need to signin first to post something..")
#      65 print("\n")
# ---> 66 self.menu()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:31, in Chatbook.menu(self)
#      28     self.my_post()
#      30 elif user_input == "4":
# ---> 31     self.sendmsg()
#      33 else:
#      34     exit()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:76, in Chatbook.sendmsg(self)
#      74     print("You need to signup first to post something..")
#      75 print("\n")
# ---> 76 self.menu()
#
# File ~\Downloads\MLOPS\OOPS Python\oops_project.py:34, in Chatbook.menu(self)
#      31     self.sendmsg()
#      33 else:
# ---> 34     exit()
#
# NameError: name 'exit' is not defined

# %%
class employee :
    # special methos/magic method//dunder method -constructor
    def __init__(self):
        print(id(self))
        # print("Started executing attribute/data")
        self.id=33
        self.salary=50000
        self.designation ="SDE"
        # print("attributes/data have been initialized")

    def travel(destination):
        print("This travel method was called manually")
        print(f"Employee is travelling to delhi")
# create an object/instance of class
sam=employee()
print(id(sam))

anu=employee()
print(id(anu))

# sam.travel()
# Out:
# 2360981746512
# 2360981746512
# 2360981740816
# 2360981740816

# %%
class employe:
    def __init__(self):
        self.id=123
        self.salary=50000
        self.description="SDE"

    def travel(self):
        print("This travel method was called manually")
        print(f"employee is now travelling to delhi")

a = employe()
a.name ="Anu kumari"

print(a.name)
# Out:
# Anu kumari
