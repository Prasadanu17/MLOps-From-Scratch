# %%
class employee :
    # special methos/magic method//dunder method -constructor
    def __init__(self):
        print("Started executing attribute/data")
        self.id=33
        self.salary=50000
        self.designation ="SDE"
        print("attributes/data have been initialized")

    def travel(self,destination):
        print("This travel method was called manually")
        print(f"Employee is travelling to {destination}")
# create an object/instance of class
sam=employee()

# printing the attributes
# print(sam.id)

# calling the method 
sam.travel("chennai")
# Out:
# Started executing attribute/data
# attributes/data have been initialized
# This travel method was called manually
# Employee is travelling to chennai

# %%
print(type(sam))
# Out:
# <class '__main__.employee'>

# %%
lst =[1,2,3]
my_str= "mlops playlist"
my_init =155

print(type(lst))
# Out:
# <class 'list'>

# %%
print(type(my_init))
# Out:
# <class 'int'>

# %%
lst.clear()
print(lst)
# Out:
# []

# %%
my_str.capitalize()
print(my_str)
# Out:
# mlops playlist

# %%
# Adavantages of OOps concept:
#     > You can create your own datatype -with example
a="x"
b="y"

print(a+b)
# Out:
# xy

# %%
from oops_project import Chatbook
user1= chatbook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 from oops_project import Chatbook
# ----> 2 user1= chatbook()
#
# NameError: name 'chatbook' is not defined
